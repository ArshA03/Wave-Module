# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
# import nbconvert
sys.path.append('D:\Academics\Thesis\Paper\Code\Validation')
from Wave_Module import *

# %% [markdown]
# # Set '1'

# %% [markdown]
# * At the end of the test-to-failure experiment, inner race defect occurred in bearing 3 and roller element defect in bearing 4

# %% [markdown]
# ## Bearing '3'

# %% [markdown]
# ### Healthy

# %% [markdown]
# Input Data from DataSet

# %%
Hdata = Input(r'D:\Academics\Thesis\DataBases\IMS\1st_test\2003.10.22.12.06.24')
Hdata = Hdata['channel5'].to_numpy()  # Channel 5 is the first for Bearing 3

# %% [markdown]
# FFT Spectrum

# %%
# Bearing 3 vibration data is in channel 5 and 6
Hwave = wave(data=Hdata, Fs=20000)  # this variable is in wave class and can use it's functions
Hfreq, Hmag= Hwave.FFT()

# %% [markdown]
# Plotting

# %%
fig, (ax1, ax2) = plt.subplots(ncols=1, nrows=2, constrained_layout=True, figsize=(10, 6))

############## Time WaveForm ##################
ax1.set_title('Time WaveForm')
ax1.plot(Hwave.time(), Hdata, color='k')
ax1.set_xlim(0,1)
ax1.set_ylabel('Amplitude')
ax1.set_xlabel('Time (s)')

############# FFT Spectrum ####################
ax2.set_title('FFT Spectrum')
ax2.plot(Hfreq, Hmag)
ax2.set_ylim(0, 0.1)
ax2.set_xlim(0, 10000)
ax2.set_xlabel('Frequency in Hertz [Hz]')
ax2.set_ylabel('Frequency Domain (Spectrum) Magnitude')
# Out:
# Text(0, 0.5, 'Frequency Domain (Spectrum) Magnitude')

# %% [markdown]
# ### Faulty

# %% [markdown]
# Input Data from DataSet

# %%
Fdata = Input(r'D:\Academics\Thesis\DataBases\IMS\1st_test\2003.11.25.23.39.56')
Fdata = Fdata['channel5'].to_numpy()

# %% [markdown]
# FFT Spectrum

# %%
# Bearing 3 vibration data is in channel 5 and 6
Fwave = wave(data=Fdata, Fs=20000)  # this variable is in wave class and can use it's functions
Ffreq, Fmag = Fwave.FFT()  # frequencies and their magnitude

# %% [markdown]
# Plotting

# %%
fig, (ax1, ax2) = plt.subplots(ncols=1, nrows=2, constrained_layout=True, figsize=(10,6))

############## Time WaveForm ##################
ax1.set_title('Time WaveForm')
ax1.plot(Fwave.time(), Fdata, color='k')
ax1.set_xlim(0,1)
ax1.set_ylabel('Amplitude')
ax1.set_xlabel('Time (s)')

############# FFT Spectrum ####################
ax2.set_title('FFT Spectrum')
ax2.plot(Ffreq, Fmag)
ax2.set_ylim(0, 0.1)
ax2.set_xlim(0, 10000)
ax2.set_xlabel('Frequency in Hertz [Hz]')
ax2.set_ylabel('Frequency Domain (Spectrum) Magnitude')
# Out:
# Text(0, 0.5, 'Frequency Domain (Spectrum) Magnitude')

# %% [markdown]
# ### Analyse

# %% [markdown]
# Bearing characteristic frequencies (Rexnord ZA-2115)

# %%
img = Image.open(r'D:\Academics\Thesis\DataBases\IMS\Capture1.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=510x372 at 0x1C9CBA48D90>

# %% [markdown]
# Plotting

# %%
Hpeaks = Hwave.peaks(prominence= 100)  # Healthy peaks location 
Fpeaks = Fwave.peaks(prominence= 100, distance=30)  # Faulty peaks location

# N is equal to Fs/L where L (number of data points 20,480) and Fs (Sample Rate 20000 Hz) 
# do not change in different data
N = 20000/20480

fig, (ax1, ax2) = plt.subplots(ncols=1, nrows=2, constrained_layout=True, figsize=(10, 6))

########## Health Data ############
ax1.set_title('Healthy')
ax1.plot(Hfreq, Hmag)
ax1.set_ylim(0, 0.06)
ax1.set_xlim(0, 1000)
ax1.set_xlabel('Frequency in Hertz [Hz]')
ax1.set_ylabel('Magnitude')
ax1.plot(Hpeaks, Hmag[[int(i) for i in Hpeaks/N]], "x")
ax1.plot(np.zeros_like(len(Hmag)), "--", color="gray")

########## Faulty Data #############
ax2.set_title('Faulty')
ax2.plot(Ffreq, Fmag)
ax2.set_ylim(0, 0.06)
ax2.set_xlim(0, 1000)
ax2.set_xlabel('Frequency in Hertz [Hz]')
ax2.set_ylabel('Magnitude')
ax2.plot(Fpeaks, Fmag[[int(i) for i in Fpeaks/N]], "x")
ax2.plot(np.zeros_like(len(Fmag)), "--", color="gray")

# %%
Fpeaks  # Faulty peak values
# Out:
# 996094e+03, 1.78125000e+03, 1.85937500e+03, 1.92480469e+03,
#        2.00292969e+03, 2.09277344e+03, 2.13085938e+03, 2.21875000e+03,
#        2.28515625e+03, 2.32519531e+03, 2.36230469e+03, 2.42578125e+03,
#        2.49316406e+03, 2.57714844e+03, 2.61523438e+03, 2.65625000e+03,
#        2.68847656e+03, 2.72851562e+03, 2.76269531e+03, 2.85546875e+03,
#        2.92382812e+03, 2.96679688e+03, 3.01855469e+03, 3.05664062e+03,
#        3.09082031e+03, 3.12597656e+03, 3.18457031e+03, 3.21679688e+03,
#        3.30468750e+03, 3.45214844e+03, 3.53710938e+03, 3.63867188e+03,
#        3.74609375e+03, 3.78125000e+03, 3.82617188e+03, 3.85937500e+03,
#        3.90332031e+03, 3.93261719e+03, 4.00683594e+03, 4.05468750e+03,
#        4.08593750e+03, 4.12011719e+03, 4.16503906e+03, 4.20605469e+03,
#        4.25976562e+03, 4.32812500e+03, 4.39257812e+03, 4.45019531e+03,
#        4.48925781e+03, 4.52441406e+03, 4.58789062e+03, 4.62011719e+03,
#        4.66015625e+03, 4.69531250e+03, 4.75195312e+03, 4.81054688e+03,
#        4.85937500e+03, 4.89550781e+03, 4.92578125e+03, 4.97167969e+03,
#        5.00878906e+03, 5.06054688e+03, 5.10644531e+03, 5.13574219e+03,
#        5.19238281e+03, 5.22265625e+03, 5.25195312e+03, 5.30664062e+03,
#        5.33984375e+03, 5.37792969e+03, 5.41015625e+03, 5.44433594e+03,
#        5.47656250e+03, 5.50781250e+03, 5.54101562e+03, 5.57324219e+03,
#        5.60546875e+03, 5.63671875e+03, 5.67187500e+03, 5.70898438e+03,
#        5.74218750e+03, 5.80175781e+03, 5.83300781e+03, 5.87402344e+03,
#        5.94921875e+03, 6.01171875e+03, 6.09667969e+03, 6.12597656e+03,
#        6.20800781e+03, 6.25683594e+03, 6.31738281e+03, 6.36035156e+03,
#        6.38964844e+03, 6.44042969e+03, 6.50585938e+03, 6.54394531e+03,
#        6.63671875e+03, 6.67578125e+03, 6.72753906e+03, 6.79980469e+03,
#        6.88964844e+03, 6.92578125e+03, 6.96289062e+03, 6.99707031e+03,
#        7.05371094e+03, 7.12109375e+03, 7.15527344e+03, 7.20703125e+03,
#        7.43457031e+03, 9.02441406e+03, 9.05371094e+03, 9.08691406e+03,
#        9.33593750e+03])

# %%
Hpeaks
# Out:
# array([493.1640625, 986.328125 ])

# %% [markdown]
# Since Bearing Fault occurs in high frequencies and they also have high energies, it is necessary to use Enveloped signal for analysing.

# %% [markdown]
# Here we used Hilbert Function to envelope the vibration signal.

# %% [markdown]
# Enveloped FFT

# %%
########### Healthy ############
Henv = envelope(data=Hdata, Fs=20000)
Hfreq_env, Hmag_env = Henv.FFT()

########## Faulty #############
Fenv = envelope(data=Fdata, Fs=20000)
Ffreq_env, Fmag_env = Fenv.FFT()

# %%
Hpeaks = Henv.peaks(prominence= 100)  # Healthy peaks location 
Fpeaks = Fenv.peaks(prominence= 50, threshold=130, distance=30)  # Faulty peaks location

fig, (ax1, ax2) = plt.subplots(ncols=1, nrows=2, constrained_layout=True, figsize=(10, 6))

########## Healthy Data ###########
ax1.set_title('Healthy (Enveloped FFt Spectrum)')
ax1.plot(Hfreq_env, Hmag_env)
ax1.set_ylim(0, 0.06)
ax1.set_xlim(0, 1000)
# ax1.set_xlabel('Frequency in Hertz [Hz]')
ax1.set_ylabel('Magnitude')
ax1.plot(Hpeaks, (Hmag_env)[[int(i) for i in Hpeaks/N]], "x")
ax1.plot(np.zeros_like(len(Hmag_env)), "--", color="gray")

########## Faulty Data #############
ax2.set_title('Faulty (Enveloped FFt Spectrum)')
ax2.plot(Ffreq_env, Fmag_env)
ax2.set_ylim(0, 0.15)
ax2.set_xlim(0, 1000)
ax2.set_xlabel('Frequency in Hertz [Hz]')
ax2.set_ylabel('Magnitude')
ax2.plot(Fpeaks, (Fmag_env)[[int(i) for i in Fpeaks/N]], "x")
ax2.plot(np.zeros_like(len(Fmag_env)), "--", color="gray")

# %%
Fpeaks # The Peak values in Faulty data
# Out:
# array([1.95312500e+00, 3.32031250e+01, 6.34765625e+01, 9.86328125e+01,
#        1.31835938e+02, 1.62109375e+02, 1.95312500e+02, 2.30468750e+02,
#        2.60742188e+02, 2.93945312e+02, 3.59375000e+02, 3.92578125e+02,
#        4.25781250e+02, 5.21484375e+02, 5.54687500e+02, 6.20117188e+02,
#        6.83593750e+02, 7.47070312e+02, 7.82226562e+02, 8.15429688e+02,
#        8.78906250e+02, 9.52148438e+02, 9.86328125e+02, 1.05078125e+03,
#        1.10937500e+03, 1.18261719e+03, 1.37011719e+03, 1.80957031e+03,
#        3.85839844e+03, 5.04492188e+03, 9.05664062e+03])

# %% [markdown]
# As we can see above, Bearing Vibration has a peak value in 293 Hz which is approximately equal to the BPFI of Bearing (296Hz).

# %% [markdown]
# ## Bearing '4'

# %% [markdown]
# ### Healthy

# %% [markdown]
# Input Data from Dataset

# %%
Hdata = Input(r'D:\Academics\Thesis\DataBases\IMS\1st_test\2003.10.22.12.06.24')
Hdata = Hdata['channel7'].to_numpy()  # Channel 7 is the first channel for Bearing 4

# %% [markdown]
# FFT Spectrum

# %%
# Bearing 4 vibration data is in channel 7 and 8
Hwave = wave(data=Hdata, Fs=20000)  # this variable is in wave class and can use it's functions
Hfreq, Hmag= Hwave.FFT()

# %% [markdown]
# Plotting

# %%
fig, (ax1, ax2) = plt.subplots(ncols=1, nrows=2, constrained_layout=True, figsize=(10, 6))

############## Time WaveForm ##################
ax1.set_title('Time WaveForm')
ax1.plot(Hwave.time(), Hdata, color='k')
ax1.set_xlim(0,1)
ax1.set_ylabel('Amplitude')
ax1.set_xlabel('Time (s)')

############# FFT Spectrum ####################
ax2.set_title('FFT Spectrum')
ax2.plot(Hfreq, Hmag)
ax2.set_ylim(0, 0.1)
ax2.set_xlim(0, 10000)
ax2.set_xlabel('Frequency in Hertz [Hz]')
ax2.set_ylabel('Frequency Domain (Spectrum) Magnitude')
# Out:
# Text(0, 0.5, 'Frequency Domain (Spectrum) Magnitude')

# %% [markdown]
# ### Faulty

# %% [markdown]
# Imput Data from DataSet

# %%
Fdata = Input(r'D:\Academics\Thesis\DataBases\IMS\1st_test\2003.11.25.23.39.56')
Fdata = Fdata['channel7'].to_numpy()

# %% [markdown]
# FFT Spectrum

# %%
# Bearing 4 vibration data is in channel 7 and 8
Fwave = wave(data=Fdata, Fs=20000)  # This variable is in wave class and can use it's functions
Ffreq, Fmag = Fwave.FFT()  # Frequencies and their magnitude

# %% [markdown]
# Plotting

# %%
fig, (ax1, ax2) = plt.subplots(ncols=1, nrows=2, constrained_layout=True, figsize=(10,6))

############## Time WaveForm ##################
ax1.set_title('Time WaveForm')
ax1.plot(Fwave.time(), Fdata, color='k')
ax1.set_xlim(0,1)
ax1.set_ylabel('Amplitude')
ax1.set_xlabel('Time (s)')

############# FFT Spectrum ####################
ax2.set_title('FFT Spectrum')
ax2.plot(Ffreq, Fmag)
ax2.set_ylim(0, 0.1)
ax2.set_xlim(0, 10000)
ax2.set_xlabel('Frequency in Hertz [Hz]')
ax2.set_ylabel('Frequency Domain (Spectrum) Magnitude')
# Out:
# Text(0, 0.5, 'Frequency Domain (Spectrum) Magnitude')

# %% [markdown]
# ### Analyse

# %% [markdown]
# Bearing characteristic frequencies (Rexnord ZA-2115)

# %%
img = Image.open(r'D:\Academics\Thesis\DataBases\IMS\Capture1.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=510x372 at 0x1C9CE9444C0>

# %% [markdown]
# Plotting

# %%
Hpeaks = Hwave.peaks(prominence= 100)  # Healthy peaks location 
Fpeaks = Fwave.peaks(prominence= 100, distance=30)  # Faulty peaks location
# N is equal to Fs/L where L (size of data) and Fs do not change in different data

fig, (ax1, ax2) = plt.subplots(ncols=1, nrows=2, constrained_layout=True, figsize=(10, 6))

########## Health Data ############
ax1.set_title('Healthy')
ax1.plot(Hfreq, Hmag)
ax1.set_ylim(0, 0.06)
ax1.set_xlim(0, 1000)
ax1.set_xlabel('Frequency in Hertz [Hz]')
ax1.set_ylabel('Magnitude')
ax1.plot(Hpeaks, (Hmag)[[int(i) for i in Hpeaks/N]], "x")
ax1.plot(np.zeros_like(len(Hmag)), "--", color="gray")

########## Faulty Data #############
ax2.set_title('Faulty')
ax2.plot(Ffreq, Fmag)
ax2.set_ylim(0, 0.06)
ax2.set_xlim(0, 1000)
ax2.set_xlabel('Frequency in Hertz [Hz]')
ax2.set_ylabel('Magnitude')
ax2.plot(Fpeaks, (Fmag)[[int(i) for i in Fpeaks/N]], "x")
ax2.plot(np.zeros_like(len(Fmag)), "--", color="gray")

# %%
Fpeaks  # Faulty Peak Value
# Out:
# array([ 392.578125 ,  489.2578125,  914.0625   ,  987.3046875,
#        1395.5078125, 1860.3515625, 2023.4375   , 2056.640625 ,
#        2092.7734375, 2122.0703125, 2333.0078125, 2565.4296875,
#        2797.8515625, 2897.4609375, 2970.703125 , 3172.8515625,
#        3217.7734375, 3262.6953125, 3485.3515625, 3760.7421875,
#        3804.6875   , 3859.375    , 3892.578125 , 3925.78125  ,
#        3960.9375   , 3996.09375  , 4038.0859375, 4088.8671875,
#        4131.8359375, 4164.0625   , 4197.265625 ])

# %%
Hpeaks  # Healthy Peak Value
# Out:
# array([986.328125])

# %% [markdown]
# Enveloped FFT

# %%
########### Healthy ############
Henv = envelope(data=Hdata, Fs=20000)
Hfreq_env, Hmag_env = Henv.FFT()

########## Faulty #############
Fenv = envelope(data=Fdata, Fs=20000)
Ffreq_env, Fmag_env = Fenv.FFT()

# %%
Hpeaks = Henv.peaks(prominence= 100)  # Healthy peaks location 
Fpeaks = Fenv.peaks(prominence= 100, threshold=80, distance=30)  # Faulty peaks location

fig, (ax1, ax2) = plt.subplots(ncols=1, nrows=2, constrained_layout=True, figsize=(10, 6))

########## Healthy Data ###########
ax1.set_title('Healthy (Enveloped FFt Spectrum)')
ax1.plot(Hfreq_env, Hmag_env)
ax1.set_ylim(0, 0.06)
ax1.set_xlim(0, 1000)
# ax1.set_xlabel('Frequency in Hertz [Hz]')
ax1.set_ylabel('Magnitude')
ax1.plot(Hpeaks, (Hmag_env)[[int(i) for i in Hpeaks/N]], "x")
ax1.plot(np.zeros_like(len(Hmag_env)), "--", color="gray")

########## Faulty Data #############
ax2.set_title('Faulty (Enveloped FFt Spectrum)')
ax2.plot(Ffreq_env, Fmag_env)
ax2.set_ylim(0, 0.15)
ax2.set_xlim(0, 1000)
ax2.set_xlabel('Frequency in Hertz [Hz]')
ax2.set_ylabel('Magnitude')
ax2.plot(Fpeaks, (Fmag_env)[[int(i) for i in Fpeaks/N]], "x")
ax2.plot(np.zeros_like(len(Fmag_env)), "--", color="gray")

# %%
Fpeaks  # Faulty Peak Value
# Out:
# array([  14.6484375,   65.4296875,   98.6328125,  195.3125   ,
#         260.7421875,  521.484375 ,  848.6328125,  914.0625   ,
#         947.265625 , 1860.3515625, 3859.375    , 4197.265625 ])

# %% [markdown]
# This demonstrates that the Ball Spin Frquency (BSF) is roughly induced as we have a peak value at 260 Hz and it is accompanied by Cage Failing Frequency (FTF) at 14 Hz.
